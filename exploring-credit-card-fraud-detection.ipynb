# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
#load the dataset to a Pandas DataFrame
df = pd.read_csv('/kaggle/input/credit-card-fraud-detection/creditcard (1).csv')

# %%
#first 5 rows of the dataset
df.head()

# %%
#last 5 rows of the dataset
df.tail()

# %%
#dataset information
df.info()

# %%
#checking the number of missing values in each column
df.isna().sum()

# %%
df.groupby(['Class']).count()

# %% [markdown]
# **This dataset is Highly unbalanced**
#
# 0--> Normal Transaction
# 1--> Fraudulent Transaction

# %% [markdown]
# **Comparing the Values for both Transaction using mean**

# %%
df.groupby(['Class']).mean()

# %%
#splitting the data into features and Tragets

X = df.drop(['Time','Class'],axis=1)
Y = df.iloc[:,-1]

# %%
print(X)

# %%
print(Y)

# %%
#split the data into training and testing data
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %% [markdown]
# **Model Training**
# Logistic Regression

# %%
model = LogisticRegression()

# %%
#training Logistic Regression model with Training data
model.fit(X_train,Y_train)

# %%
model.score(X_train,Y_train)

# %%
model.score(X_test,Y_test)

# %% [markdown]
# **Classification Report**

# %%
from sklearn.metrics import classification_report

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(Y_test,y_pred))

# %% [markdown]
# ****1--> has poor precision,recall,f1-score,support ****

# %% [markdown]
# **Over Sampling**

# %% [markdown]
# Building a sample dataset containing similar distribution of Normal transaction and Fraudulent transaction

# %%
from imblearn.over_sampling import SMOTE

# %%
upsample = SMOTE()

# %%
X,Y= upsample.fit_resample(X,Y)

# %% [markdown]
# **Counting the Number of Normal Transactions and Fraudulent Transactions**

# %%
from collections import Counter

# %%
count= Counter(Y)

# %%
print(count)

# %% [markdown]
# 0--> 284315
# 1--> 284315

# %%
#split the data into training and testing data
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
model.score(X_train,Y_train)

# %%
model.score(X_test,Y_test)

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict(X_train)

# %%
accuracy_score(y_pred,Y_train)

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_pred,Y_test)
